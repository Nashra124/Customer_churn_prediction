# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Telco_Customer_Churn_Dataset  (3).csv')

# %%
#check the data
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#What question are you trying to answer?
# check the churn ,y does people is leaving how much time does

# %%
#see the columns
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#drop unnecessary columns
df = df.drop(columns=['customerID'], axis=1)

# %%
#check that column is present or not
df.head(10)
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
# 5  Female              0      No         No       8          Yes
# 6    Male              0      No        Yes      22          Yes
# 7  Female              0      No         No      10           No
# 8  Female              0     Yes         No      28          Yes
# 9    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
#get stats of data
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
#check null values
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#scheck duplicate values
df.duplicated().unique()
# Out:
# array([False,  True])

# %%
#drop duplicate values
df= df.drop_duplicates()

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# 1. Replace empty spaces with '0'
df['TotalCharges'] = df['TotalCharges'].replace(' ', '0')

# 2. Convert to float safely
df['TotalCharges'] = df['TotalCharges'].astype(float)

# %%
#check duplicate values
df.duplicated().unique()
# Out:
# array([False])

# %%
sns.barplot(data=df,x='gender',y='Churn',hue='Contract')
# Out:
# <Axes: xlabel='gender', ylabel='Churn'>

# %%
sns.barplot(data=df,x='PaymentMethod',y='Churn')
# Out:
# <Axes: xlabel='PaymentMethod', ylabel='Churn'>

# %%
#check for unique values
for col in df.columns:
  print(f'column:{col} : unique value is {df[col].unique()} | count of unique value {df[col].nunique()}')
# Out:
# column:gender : unique value is ['Female' 'Male'] | count of unique value 2
# column:SeniorCitizen : unique value is [0 1] | count of unique value 2
# column:Partner : unique value is ['Yes' 'No'] | count of unique value 2
# column:Dependents : unique value is ['No' 'Yes'] | count of unique value 2
# column:tenure : unique value is [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39] | count of unique value 73
# column:PhoneService : unique value is ['No' 'Yes'] | count of unique value 2
# column:MultipleLines : unique value is ['No phone service' 'No' 'Yes'] | count of unique value 3
# column:InternetService : unique value is ['DSL' 'Fiber optic' 'No'] | count of unique value 3
# column:OnlineSecurity : unique value is ['No' 'Yes' 'No internet service'] | count of unique value 3
# ...

# %%
#check unique values which are having more than 2 unique values
for col in df.columns:
  if df[col].nunique() ==2 and df[col].dtype=='object':
    print(f'column:{col} : unique value is {df[col].unique()} | count of unique value {df[col].nunique()}')
# Out:
# column:gender : unique value is ['Female' 'Male'] | count of unique value 2
# column:Partner : unique value is ['Yes' 'No'] | count of unique value 2
# column:Dependents : unique value is ['No' 'Yes'] | count of unique value 2
# column:PhoneService : unique value is ['No' 'Yes'] | count of unique value 2
# column:PaperlessBilling : unique value is ['Yes' 'No'] | count of unique value 2
# column:Churn : unique value is ['No' 'Yes'] | count of unique value 2

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
le = LabelEncoder()
ohe = OneHotEncoder(sparse_output=False, handle_unknown='ignore').set_output(transform="pandas")

# %%
#text columns to encoder
encoder = ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
ohe_encoder = ['InternetService', 'Contract','PaymentMethod']

# %%
for i in encoder:
  df[i] = le.fit_transform(df[i])

df_ohe = ohe.fit_transform(df[ohe_encoder])
df = df.drop(columns=ohe_encoder)
df = pd.concat([df.reset_index(drop=True), df_ohe.reset_index(drop=True)], axis=1)

# %%
replaced_values = {'No internet service':'No',
    'No phone service':'No'}

# Identify the columns that contain these specific values
columns_to_replace = [
    'MultipleLines', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies'
]

for col_name in columns_to_replace:
    if col_name in df.columns:
        df[col_name] = df[col_name].replace(replaced_values)

# %%
x = df.drop(columns=['Churn'])
y = df['Churn']

# %%
from sklearn.model_selection import train_test_split

# 1. Split the data
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=700)

# %%
#check the target variable is balanced or not
sns.countplot(data=df,x=y)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
#balance the data
from imblearn.over_sampling import SMOTE
smote = SMOTE()
x_train_smote,y_train_smote = smote.fit_resample(x_train,y_train)

# %% [markdown]
# logistic regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train_smote,y_train_smote)
y_pred_lr = lr.predict(x_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# knn

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train_smote,y_train_smote)
y_pred_knn = knn.predict(x_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train_smote,y_train_smote)
y_pred_dt = dt.predict(x_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42)
rf.fit(x_train, y_train)
y_pred_rf = rf.predict(x_test)

# %% [markdown]
# ensemble learninh

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(
    n_estimators=100,
    random_state=42
)
ada.fit(x_train, y_train)
y_pred_ada = ada.predict(x_test)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(
    n_estimators=100,
    learning_rate=0.1,
    random_state=42)
gb.fit(x_train, y_train)
y_pred_gb = gb.predict(x_test)

# %%
# !pip install xgboost
from xgboost import XGBClassifier
xgb = XGBClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    random_state=42
)
xgb.fit(x_train, y_train)
y_pred_xgb = xgb.predict(x_test)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
svm = SVC()
svm.fit(x_train_scaled, y_train)
y_pred_svm = svm.predict(x_test_scaled)

# %%
from sklearn.metrics import accuracy_score,roc_auc_score,confusion_matrix

# %%
evaluations = {
    'LogisticRegression': y_pred_lr,
    'KNeighborsClassifier': y_pred_knn,
    'DecisionTreeClassifier': y_pred_dt,
    'RandomForestClassifier': y_pred_rf,
    'AdaBoostClassifier': y_pred_ada,
    'GradientBoostingClassifier': y_pred_gb,
    'XGBClassifier': y_pred_xgb,
    'SVC': y_pred_svm
}

for model_name, y_pred in evaluations.items():#.itms() is used to loop through dict using key and value
    # For SVC and KNN, x_test was scaled, but the y_test should remain the same
    # All y_pred are already based on y_test
    evaluate_model(model_name, y_test, y_pred)
# Out:
# --- LogisticRegression ---
# Accuracy: 0.7483
# ROC AUC: 0.7464
# ----------------------
# --- KNeighborsClassifier ---
# Accuracy: 0.7284
# ROC AUC: 0.5000
# ----------------------
# --- DecisionTreeClassifier ---
# Accuracy: 0.6469
# ROC AUC: 0.6794
# ----------------------
# --- RandomForestClassifier ---
# Accuracy: 0.7762
# ROC AUC: 0.6834
# ----------------------
# --- AdaBoostClassifier ---
# Accuracy: 0.8007
# ROC AUC: 0.7113
# ----------------------
# --- GradientBoostingClassifier ---
# Accuracy: 0.7990
# ROC AUC: 0.7049
# ----------------------
# --- XGBClassifier ---
# Accuracy: 0.7938
# ROC AUC: 0.7027
# ----------------------
# --- SVC ---
# Accuracy: 0.7904
# ROC AUC: 0.6931
# ----------------------
